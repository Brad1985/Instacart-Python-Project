# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# setting path

path = r'/Users/brad/Desktop/Instacart Basket Analysis'

# %%
# Importing the order file
df_orders_products_combined = pd.read_pickle(r'/Users/brad/Desktop/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_combined_v2.pkl')

# %%
# Q4 -heck the shape
df_orders_products_combined.shape
# Out:
# (32434489, 13)

# %% [markdown]
# Same shape as exported file

# %%
# Q5 - Import wrangled products dataset
df_prods = pd.read_csv(r'/Users/brad/Desktop/Instacart Basket Analysis/02 Data/Prepared Data/prods_consistency.csv', index_col = False)

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49688       49688       49684
# 49689       49689       49685
# 49690       49690       49686
# 49691       49691       49687
# 49692       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49688          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
df_orders_products_combined
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                    0           0   2539329        1    prior             1
# 1                    0           0   2539329        1    prior             1
# 2                    0           0   2539329        1    prior             1
# 3                    0           0   2539329        1    prior             1
# 4                    0           0   2539329        1    prior             1
# ...                ...         ...       ...      ...      ...           ...
# 32434484       3421081     3421081   2977660   206209    prior            13
# 32434485       3421081     3421081   2977660   206209    prior            13
# 32434486       3421081     3421081   2977660   206209    prior            13
# 32434487       3421081     3421081   2977660   206209    prior            13
# 32434488       3421081     3421081   2977660   206209    prior            13
#
# ...

# %% [markdown]
# - Product_id is the common key/value across the dataframes

# %%
df_orders_products_combined=df_orders_products_combined.drop(columns=['_merge'])

# %%
# Merging datasets through common key "product_id" - inner join
df_merged = df_orders_products_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
df_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             1   2398795        1    prior             2
# 2             2             2    473747        1    prior             3
# 3             3             3   2254736        1    prior             4
# 4             4             4    431534        1    prior             5
#
#    orders_day_of_the_week  order_hour_of_day  days_since_prior_order  \
# 0                       2                  8                     NaN
# 1                       3                  7                    15.0
# 2                       3                 12                    21.0
# 3                       4                  7                    29.0
# 4                       4                 15                    28.0
#
#    product_id  add_to_cart_order  reordered  Unnamed: 0_y product_name  \
# ...

# %%
# Q6. Confirm using the merge flag
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
#Q7 - Export orders_products_merged folder
path = r'/Users/brad/Desktop/Instacart Basket Analysis'

# %%
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_v2.pkl'))

# %%
df_merged.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.csv'))
